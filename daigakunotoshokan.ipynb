# %%
import pandas as pd
import os


f = open("daigakunotoshokan.json")
os.close(f.fileno())
del f


df = pd.read_excel(r"./図書館情報学文献目録』(BIBLIS PLUS)1.xlsx", index_col=0)
# print(df)
# df.to_json(r"C:\Users\onowa\OneDrive\Documents\dtk\daigakunotoshokan.jsonl", orient='records', force_ascii=False, lines=True)

# %%
df
# Out:
#                                      Title          特集          大学の図書館  \
# 0
# 3                            大学図書館に働く皆さんへ          NaN  大学図書館の問題を語る会会報
# 4                                実践的研究団体を          NaN  大学図書館の問題を語る会会報
# 7           大学図書館は学生のために一日図研第11回研究大会に参加して          NaN  大学図書館の問題を語る会会報
# 8              大学図書館の現状とそのあり方一図全協全国研究集会報告          NaN  大学図書館の問題を語る会会報
# 9                             図書館の現状一東洋大学          NaN  大学図書館の問題を語る会会報
# ...                                    ...         ...             ...
# 5201    北海道大学附属図書館所蔵「北方資料コレクション」の選定・収集について  選書、どうしてますか          大学の図書館
# 5202           オンラインイベント「選書、どうしてますか?」に参加して  選書、どうしてますか          大学の図書館
# 5203                   北海道地域グループのイベントに参加して  選書、どうしてますか          大学の図書館
# 5204  北海道地域グループオンラインイベント「選書、どうしてますか?」に参加して  選書、どうしてますか          大学の図書館
# 5205   北海道地域グループオンラインイベント「選書、どうしてますか?」参加報告  選書、どうしてますか          大学の図書館
#
#          発行年月    通巻    巻    号 開始ページ 終了ページ 号単位NDL永続識別子  ... Author10.1 Author元  \
# ...

# %%
path = r"./daigakunotoshokan.json"

df.to_json(path, orient='records', force_ascii=False)

# %%
df.to_csv(r"C:\Users\onowa\test.csv")
